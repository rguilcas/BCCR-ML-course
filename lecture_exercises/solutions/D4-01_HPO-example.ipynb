# %% [markdown]
# # Hyperparameter optimisation
#
# In this notebook we will explore hyperparameter optimisation, and consider a couple of methods for doing so. The goal is for you to know more about what happens under the hood.

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
import os

if os.getenv("COLAB_RELEASE_TAG") is None:
    DATA_IN_PATH = '../data'
else:
    DATA_IN_PATH = 'https://raw.githubusercontent.com/rguilcas/BCCR-ML-course/refs/heads/hpo-exercises/lecture_exercises/data'

score_label = 'Validation accuracy'

# %%
def decorate_plot(ax, xlabel=None, ylabel=None, legend=False):
    if xlabel:
        ax.set_xlabel(xlabel)
    if ylabel:
        ax.set_ylabel(ylabel)
    ax.spines[['right', 'top']].set_visible(False)
    if legend:
        ax.legend(frameon=False)
    ax.xaxis.set_major_locator(plt.MultipleLocator(5))
    ax.xaxis.set_minor_locator(plt.MultipleLocator(1))
    ax.set_xlim(0,20)

def double_plot(ax, xx, yy, col, label, ll=None, aa=1):
    # Do the plotting twice, because we only want to add to the legend once
    ax.plot(xx, yy.T.iloc[0].T, c=col, linestyle=ll, alpha=aa,
                label=label);
    ax.plot(xx, yy, c=col, linestyle=ll, alpha=aa,);

# %% [markdown]
# # Exploring the data
# Because running a hyperparameter sweep to collect the performance of many hyperparameters can be time-consuming, we will rely on the results of a previous saved sweep.

# %%
# First we load in the validation accuracy for the runs over successive epochs
score_df = pd.read_csv(DATA_IN_PATH+'/hpo-sweeps/pandas-8-score_df.csv', index_col=0).T.reset_index(drop=True)
score_df.index = score_df.index.rename('epoch')

score_df
max_score_df = score_df.max()

# %%
# We also load the corresponding hyperparameter choices for each run
df_hyperparams = pd.read_json(DATA_IN_PATH+'/hpo-sweeps/pandas-8-config_dict.json').T
config_dict = df_hyperparams.to_dict(orient='index')

# %%
config_dict['vqysm9hn']
# Out:
# {'C2': 21,
#  'C3': 15,
#  'lr': 0.006571808845751719,
#  'L1_expo': 2,
#  'L2_expo': 3,
#  'optimizer': 'SGD'}

# %%
# Lets pick some colours to distinguish the different optimizer choices.
col_dict = {'SGD': 'C0',
           'Adam': 'C1',
           'AdamW': 'C2'}

# %% [markdown]
# ## Lets first look at each hyperparameter individually

# %% [markdown]
# ### Question 1:
# Fill in the HPs we've explored below to inspect their impact on performance. For now, keep the optimiser separate.

# %%
col_dict = {'SGD': 'C0',
           'Adam': 'C1',
           'AdamW': 'C2'}

for HP in ['lr', 'C2', 'C3', 'L1_expo', 'L2_expo']:
    fig, ax = plt.subplots()
    for run_id in config_dict.keys():
        ax.scatter(config_dict[run_id][HP], 
                    max_score_df[max_score_df.index == run_id],
                   color=col_dict[config_dict[run_id]['optimizer']])
    decorate_plot(ax, HP, score_label)
    if HP == 'lr':
        plt.xscale('log')
        ax.set_xlabel(HP + ' (log axis)')

# %% [markdown]
# ### Question 2:
# What conclusions can you draw from the above plots?

# %% [markdown]
# ## Optimisers
# For the optimisers we can compare histograms of the final performance

# %% [markdown]
# ### Question 3:
# Fill in the missing code to create the necessary lists of run_ids and a set of histograms of the performance of each optimiser.

# %%
# Separate the runs by which optimiser was used
sgd_runs = [run_id for run_id in config_dict.keys() if config_dict[run_id]['optimizer'] == 'SGD']
adam_runs = [run_id for run_id in config_dict.keys() if config_dict[run_id]['optimizer'] == 'Adam']
adamw_runs = [run_id for run_id in config_dict.keys() if config_dict[run_id]['optimizer'] == 'AdamW']

# %%
bins = np.linspace(15, 65, 21)
fig, axes = plt.subplots(3, 1)
ii = 0
for label, sub_list in [('SGD', sgd_runs), ('Adam', adam_runs), ('AdamW', adamw_runs)]:
    ax = axes[ii]
    ax.hist(max_score_df.T[sub_list].T.values, label=label, alpha=0.5, bins=bins,
             density=True, color=col_dict[label])
    decorate_plot(ax, score_label, None, legend=True)
    ax.set_ylim([0, 0.15])
    ii += 1

# %% [markdown]
# Because we picked the optimiser randomly for each run we do not have an equal amount of runs for each optimiser.

# %%
for label, sub_list in [('SGD', sgd_runs), ('Adam', adam_runs), ('AdamW', adamw_runs)]:
    print(label, len(sub_list))
# Out:
# SGD 17
# Adam 26
# AdamW 21

# %% [markdown]
# ### Question 4:
# If you were to set up more experiments which optimisers would you use? Why?

# %% [markdown]
# # Hyperparameter optimisation methods
# ## Successive halving
#
# The successive halving algorithm is designed to greedily discard low-performing models, so that the hyperparamter optimisation budget can be focussed on high-performing configurations. To do so, at every decision step it only keeps the best 1/**H** runs, and discards the rest. It will then run the remaining runs for **H** times as long as for the previous choice. Here we will use **H**=2, so we will discard the bottom half, and for each such discarding choice double the number of epochs trained before the next decision point. If you want to learn more, see e.g. https://blog.ml.cmu.edu/2018/12/12/massively-parallel-hyperparameter-optimization/
#
# As before, we will take advantage of the existing run that we have on record in order to speed up our exploration.
#
# ### Question 5:
# Fill in the missing parts of the code so we can implement successive halving

# %%
    

disc_list, median_list, splits = [], [], [] # We want to store some intermediate states
kept_step_prev = score_df
cc = 0 # Tracking which epoch we're using.
main_fig, main_ax = plt.subplots()
for ii in range(1, 5):
    cc = cc + 2**(ii-1) # Update which epoch we'll look at when splitting
    splits.append(cc) # Record keeping
    cur_step = f'step {cc}'
    step_cur_median = kept_step_prev[cur_step].median() # Take the middle value as the threshold
    median_list.append(step_cur_median)
    
    # Create two new data frames, one for the runs we're keeping, and one for the one we're dropping
    kept_step_cur = kept_step_prev[kept_step_prev[cur_step] > step_cur_median]
    disc_step_cur = kept_step_prev[kept_step_prev[cur_step] <= step_cur_median]
    disc_list.append(disc_step_cur) # Track all the runs we're discarding

    kept_step_prev = kept_step_cur # Update varible
    print(f'{cur_step}, threshold: {step_cur_median}, num runs left: {len(kept_step_cur)}')

    # Add the discarded runs to our main figure
    # Do the plotting twice, because we only want to add to the legend once
    col = f'C{ii-1}'
    double_plot(main_ax, range(cc+1), disc_step_cur.T[:cc+1], col=col,
                label=f'Discarded epoch {cc}')

    # Also make a figure for this decision point
    fig, ax = plt.subplots()
    double_plot(ax, range(cc+1), disc_step_cur.T[:cc+1], col=col, label='Discarded: observed')
    double_plot(ax, range(21), disc_step_cur.T, col=col, label='Discarded: future',
                ll=':', aa=0.5)
    double_plot(ax, range(cc+1), kept_step_cur.T[:cc+1], label='Kept: observed', col='k', aa=0.5)
    double_plot(ax, range(21), kept_step_cur.T, col='k', label='Kept: future', ll=':', aa=0.5)
    decorate_plot(ax, 'Epoch', score_label, legend=True)
    ax.set_title(f'Step {ii}')
kept_final = kept_step_prev
double_plot(main_ax, range(21), kept_final.T, col='k', label='Kept')
decorate_plot(main_ax, 'Epoch', score_label, legend=True)
# Out:
# step 1, threshold: 17.2285, num runs left: 27
# step 3, threshold: 41.0487, num runs left: 13
# step 7, threshold: 51.8352, num runs left: 6
# step 15, threshold: 60.0, num runs left: 3

# %% [markdown]
# ### Question 6:
# Do you think the algoritm is reasonable in the runs that it stops early?

# %% [markdown]
# ## Learning curves
# An alternative approach is to treat the evolution of the training curves as a prediction problem, and train a simpler model to predict the evolution over epochs of the validation accuracy.
#
# Here we will train linear regression models to predict future validation accuracies based on the first **K** epochs. These could then be used to decide which runs to continue and which to stop early.

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Question 7:
# Fill in the remaining code so we can predict future accuracy.

# %%
K = 5 # How many epochs we run for before predicting the evolution. Used to split into X and y.
X = score_df.T[:K].T
y = score_df.T[K:].T

N = 40 # How many runs to use for training. Used to split into training and validation subsets.
X_train = X[:N]
y_train = y[:N]
X_val = X[N:]
y_val = y[N:]

# We fit a linear regression model to the training data
reg = LinearRegression().fit(X_train, y_train)

# %%
# Plot the predicted validation curves
fig, ax = plt.subplots()
for ii in range(10):
    X_ii = X_val.iloc[[ii]]
    y_ii = y_val.iloc[[ii]]
    ax.plot(range(K), X_ii.values[0], '--', c=f'C{ii}',
            label='Features' if ii == 0 else None);
    ax.plot(range(K, 21), reg.predict(X_ii).T, ':', c=f'C{ii}',
            label='Predicted' if ii == 0 else None);
    ax.plot(range(K, 21), y_ii.values[0], c=f'C{ii}',
            label='True' if ii == 0 else None);
ax.set_xlabel('Epoch')
ax.set_ylabel(score_label)
ax.spines[['right', 'top']].set_visible(False)
ax.set_title('Linear regression to predict future accuracy')
ax.legend(frameon=False);

# %% [markdown]
# ### Question 8:
#
# How well do the predictions work? What are they good at? How much computation could you save by using the predictions as heuristics for final performance to limit the number of models trained to end? What happens if you change **K** and **N**?
